# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PyQt6.QtWidgets import QApplication, QMainWindow, QVBoxLayout, QWidget

from matplotlib.backends.backend_qtagg import FigureCanvasQTAgg as QFigureCanvas
import sys
canvas, plot_gebied = plt.subplots()

# dataset "tips"
df = sns.load_dataset("tips")
df2 = df.groupby('day')['total_bill'].sum()

# Grafiek maken
sns.lineplot(x=df2.index, y=df2.values)
sns.lineplot(x=df2.index, y=df2.values, ax=plot_gebied)

# kpi toevoegen
plt.axhline(y=1200, color='r', linestyle='--', label='KPI omzet per dag: 1200')
plt.legend()

grafiek_canvas_widget = QFigureCanvas(canvas)
app = QApplication(sys.argv)
main_window = QMainWindow()
main_window.setWindowTitle("Seaborn en PyQT!!!")
main_window.setCentralWidget(grafiek_canvas_widget)
main_window.show()
sys.exit(app.exec())
# Out:
# C:\Users\Benjahmin\AppData\Local\Temp\ipykernel_29544\2304114879.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2 = df.groupby('day')['total_bill'].sum()
